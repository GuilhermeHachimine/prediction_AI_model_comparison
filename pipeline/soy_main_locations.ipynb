# %%
import pandas as pd
import os


# Ler o arquivo CSV usando o caminho relativo
df = pd.read_csv('../data/soy_prices.csv')

grouped = df.groupby('main_location_id')
grouped.head()
# Out:
#          id  product_id  main_location_id        date  avg_price         ask  \
# 0         1           2                13  2021-06-01  98.260000  100.930014
# 1         2           2                19  2021-06-01  94.195602   94.378171
# 2         5           2                 6  2021-05-31  77.375000         NaN
# 3        11           2                11  2021-07-08  87.000000         NaN
# 4        13           2                 8  2021-06-02  75.114286         NaN
# ...     ...         ...               ...         ...        ...         ...
# 3789  28774           2                24  2022-04-01  86.120003         NaN
# 3793  28786           2                22  2022-04-01  79.169998         NaN
# 3930  31617           2                14  2022-04-11  91.321522         NaN
# 4936  34728           2                14  2022-04-27  96.353643         NaN
# 5088  35403           2                14  2022-05-05  95.980003         NaN
#
# ...

# %%
for main_location, group in grouped:
    # Criar o diretório se não existir
    dir_path = f'../data/soy/{main_location}'
    os.makedirs(dir_path, exist_ok=True)
    
    # Salvar o arquivo CSV
    file_path = os.path.join(dir_path, 'soy_prices.csv')
    group.to_csv(file_path, index=False)
